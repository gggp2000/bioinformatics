# %%
gene = []
with open('/Users/gaopeng/Downloads/dataset_9_3 (1).txt') as f:
    for line in f.readlines():
        gene.append(line.strip())

# %%
p = 'GGGCCGTTGGT'
q = 'GGACCGTTGAC'

# %%
k=0

# %%
for i in range(len(gene[0])):
    if gene[0][i] != gene[1][i]:
        k += 1

# %%
k
# Out:
# 809
